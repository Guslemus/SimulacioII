# %% [markdown]
# # Cálculo de integrales por el método de Monte Carlo

# %% [markdown]
# Consiedramos aquí la estimación de integrales unidimensionales
#
# I = $\int_a^b g(x)dx,$
#
# suponiendo que
#
# $0 \leq g(x) \leq c$, $a \leq x \leq b$

# %% [markdown]
# ## Método de acierto y error

# %% [markdown]
# Sea $(X, Y)$ un vector aleatorio uniformemente distribuido sobre el rectángulo $\Omega$ con
# función densidad de probabilidad
#
# $f_{xY}(x, y) = \frac{1}{c(b-a)}$ si $(x,y) \in \Omega$
#
# $f_{xY}(x, y) = 0$ en otro caso.
#
#
# Si $S = {(x,y)| y \leq g(x)}$ es el área bajo la curva, la probabilidad de que $(x,y)$ caiga bajo la curva $g(x)$ es:
#
# $p = \frac{area S}{area \Omega} = \frac{\int_a^b g(x)dx}{c(b-a)} = \frac{I}{c(b-a)}$

# %% [markdown]
# Si generamos $N$ vectores aleatorios independientes $(X_1, Y_1)$, $(X_2, Y_2)$, ..., $(X_N, Y_N)$, $p$ puede
# ser estimado por:
#
# $\hat{p} = \frac{N_A}{N}$,
#
# donde $N_A$ es el número de aciertos.
#
# Y la integral puede ser estimada por:
#
# $ I\approx \theta_1 = c(b-a)\frac{N_A}{N}$

# %% [markdown]
# ## Ejercicio
#
# 1. Mostrar que $\theta_1 $ es un estimador insesgado, es decir, que $E(\theta_1 ) = pc(b-a) = I$
# 2. Mostrar que $V(\theta_1 )=\frac{I}{N}[c(b-a)-I]$

# %%
import random                                   # importamos el módulo random
import numpy as np                              # importamos numpy con un alias (np)
import matplotlib.pyplot as plt                 # ídem
import statistics as stats   
import pandas as pd
#Definimos la función de prueba.
def test_function(x):
    return(np.sqrt(np.arctan(x)))
def integrate(x1,x2,func=test_function,n=100000):
    X=np.linspace(x1,x2,1000)
    y1=0
    y2=max((func(X)))
    cc=y2
    area=(x2-x1)*(y2-y1)
    check=[]
    xs=[]
    ys=[]
    sum=0
    for i in range(n):
        x=np.random.uniform(x1,x2)
        xs.append(x)
        y=np.random.uniform(y1,y2)
        ys.append(y)
        if abs(y)>abs(func(x)) or y<0:
            check.append(0)
        else:
            check.append(1)
            sum=sum+1
    p=sum/n
    return(cc,p,np.mean(check)*area,xs,ys,check)
cc,p,I,x,y,c=integrate(0,1)
print("El valor de la integral es:",I)
_,_,_,x,y,c=integrate(0,1,n=500)
df=pd.DataFrame()
df=pd.DataFrame()
df['x']=x
df['y']=y
df['c']=c
b=1
a=0
E=(p*cc)*(b-a) # Caculamos E(theta1)
V=(I/100000)*(cc*(b-a)-I)
print("El valor de E(theta1)=",E)
print("Por lo tanto , E(theta1) = I")
print("V=(I/N)(c(b-a)-I) =",V)
X=np.linspace(0,1,1000)
plt.grid(True)
plt.plot(X,test_function(X))
plt.scatter(df[df['c']==0]['x'],df[df['c']==0]['y'],color='red')
plt.scatter(df[df['c']==1]['x'],df[df['c']==1]['y'],color='blue')
plt.show()
# Out:
# El valor de la integral es: 0.6289109376475497
# El valor de E(theta1)= 0.6289109376475497
# Por lo tanto , E(theta1) = I
# V=(I/N)(c(b-a)-I) = 1.6182883916227898e-06

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Como ejemplo, calculemos una integral no soluble por métodos analíticos:
#
# $\int_0^1 \sqrt( \arctan x ) dx$
#
# Primero, definimos y graficamos la función de prueba:

# %%
#Definimos la función de prueba.
def test_function(x):
    return(np.sqrt(np.arctan(x)))

# %%
#Graficamos la función de prueba.
X=np.linspace(0,1,1000)
plt.grid(True)
plt.title('Función de prueba', color='b')
plt.plot(X, test_function(X))
plt.show()

# %% [markdown]
# Observemos que la función es continua y monotona creciente, lo cual nos asegura que está acotada en $[0,1]$, es decir,
# podemos dibujarla completa dentro de un rectángulo.

# %%
def integrate(x1,x2,func=test_function,n=100000):
    X=np.linspace(x1,x2,1000)
    y1=0
    y2=max((func(X)))
    print(x1,x2,y1,y2)
    area=(x2-x1)*(y2-y1)
    check=[]
    xs=[]
    ys=[]
    for i in range(n):
        x=np.random.uniform(x1,x2,1)
        xs.append(x)
        y=np.random.uniform(y1,y2,1)
        ys.append(y)
        if abs(y)>abs(func(x)) or y<0:
            check.append(0)
        else:
            check.append(1)
    return(np.mean(check)*area,xs,ys,check)

# %%
#print(integrate(0,1)[0])
print(integrate(0,1,test_function)[0])
_,x,y,c=integrate(0,1,n=500)
df=pd.DataFrame()
df['x']=x
df['y']=y
df['c']=c

X=np.linspace(0,1,1000)
plt.grid(True)
plt.plot(X,test_function(X))
plt.scatter(df[df['c']==0]['x'],df[df['c']==0]['y'],color='red')
plt.scatter(df[df['c']==1]['x'],df[df['c']==1]['y'],color='blue')
plt.show()
# Out:
# 0 1 0 0.8862269254527579
# 0.6295490210338756
# 0 1 0 0.8862269254527579

# %% [markdown]
# ## Método de la media muestral

# %% [markdown]
# Reescribimos la integral $I$ como:
#
# $I = \int_a^b \frac{g(x)}{f_X(x)}f_X(x) dx$,
#
# donde $f_X(x)$ es cualquier función densidad de distribución tal que $f_X(x) > 0$ cuando $g(x)\neq 0 $
#
# Entonces:
#
# $I = E[\frac{g(X)}{f_X(X)}]$
#
#
# donde usaremos por simplicidad:
#
# $f_X(x) = \frac{1}{b-a}$ si $a<x<b$
#
# $f_X(x) = 0$ en otro caso.
#
# Asi
#
# $I = (b-a)E(g(x))$
#
# y usamos el estimador:
#
# $\theta_2 = (b-a)\frac{1}{N}\sum_{i=1}^{N}g(X_i)$

# %%
#Esta función calcula la integral usando la ley de los grandes números, es decir,
#la aproxima como el promedio del muestreo aleatorio.
def integ(func=test_function, n=10000):
    muestreo=[]
    suma=[]
    for i in range(n):
        u=np.random.random_sample()
        muestreo.append(u)
        y=func(u)
        suma.append(y)

    return(np.mean(suma))

print("El valor de la integral es:", integ())
# Out:
# El valor de la integral es: 0.6260246408873245

# %% [markdown]
# ## Ejercicio
#
# Estimar las integrales:
#
# 1. $\int_0^1 (1 - x^2)^{\frac{3}{2}} dx$
#
# 2. $\int_{-2}^2 \exp (x + x^2) dx$

# %%
#Estimar la intreal 1
#Definimos la función de prueba.
def fun_prue1(x):
    return((1-x**2)**(3/2))

# %%
#Esta función calcula la integral usando la ley de los grandes números, es decir,
#la aproxima como el promedio del muestreo aleatorio.
def integ(func=fun_prue1, n=10000):
    muestreo=[]
    suma=[]
    for i in range(n):
        u=np.random.random_sample()
        muestreo.append(u)
        y=func(u)
        suma.append(y)

    return(np.mean(suma))

print("El valor de la integral es:", integ())
# Out:
# El valor de la integral es: 0.5920229791402696

# %%
def integrate(x1,x2,func=fun_prue1,n=100000):
    X=np.linspace(x1,x2,1000)
    y1=0
    y2=max((func(X)))
    area=(x2-x1)*(y2-y1)
    check=[]
    xs=[]
    ys=[]
    for i in range(n):
        x=np.random.uniform(x1,x2,1)
        xs.append(x)
        y=np.random.uniform(y1,y2,1)
        ys.append(y)
        if abs(y)>abs(func(x)) or y<0:
            check.append(0)
        else:
            check.append(1)
    return(np.mean(check)*area,xs,ys,check)
I,x,y,c=integrate(0,1)
print("El valor de la integral es:",I)
_,x,y,c=integrate(0,1,n=500)
df=pd.DataFrame()
df['x']=x
df['y']=y
df['c']=c

X=np.linspace(0,1,1000)
plt.grid(True)
plt.plot(X,test_function(X))
plt.scatter(df[df['c']==0]['x'],df[df['c']==0]['y'],color='red')
plt.scatter(df[df['c']==1]['x'],df[df['c']==1]['y'],color='blue')
plt.show()
# Out:
# El valor de la integral es: 0.58716

# %%
from numpy.ma.core import exp
#Estimar la segunda integral
#Definimos la funcion de puebra
def fun_prue(x):
  return (exp(x+x**x))

# %%
def integrate(x1,x2,func=fun_prue,n=100000):
    X=np.linspace(x1,x2,1000)
    y1=0
    y2=max((func(X)))
    area=(x2-x1)*(y2-y1)
    check=[]
    xs=[]
    ys=[]
    for i in range(n):
        x=np.random.uniform(x1,x2,1)
        xs.append(x)
        y=np.random.uniform(y1,y2,1)
        ys.append(y)
        if abs(y)>abs(func(x)) or y<0:
            check.append(0)
        else:
            check.append(1)
    return(np.mean(check)*area,xs,ys,check)
I,x,y,c=integrate(0,1)
print("El valor de la integral es:",I)
_,x,y,c=integrate(0,1,n=500)
df=pd.DataFrame()
df['x']=x
df['y']=y
df['c']=c

X=np.linspace(0,1,1000)
plt.grid(True)
plt.plot(X,test_function(X))
plt.scatter(df[df['c']==0]['x'],df[df['c']==0]['y'],color='red')
plt.scatter(df[df['c']==1]['x'],df[df['c']==1]['y'],color='blue')
plt.show()
# Out:
# El valor de la integral es: 3.8406835791021736

# %% [markdown]
# Bibliografía
#
# Simulation and the Monte Carlo Method. Reuven Y. Rubinstein, John Wiley & Sons, 1981  (Capítulo 4)
